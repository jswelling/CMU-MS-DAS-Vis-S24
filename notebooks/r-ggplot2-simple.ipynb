# %%
library(ggplot2)

# %%
ggplot(mpg, aes(displ, hwy, colour = class)) + 
  geom_point() +
  facet_wrap(~ cyl)
# Out:
# plot without title

# %%
ggplot(mpg, aes(displ, hwy, colour = cyl)) + 
  geom_point() +
  facet_wrap(~ class)
# Out:
# plot without title
